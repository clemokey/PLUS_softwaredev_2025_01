# %%
import direction

# Display the route map from your IP location to a desired destination address
direction.process("Karl-Adrian-Strasse 3")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
# Get the directions instruction for the address
print(direction.process("Karl-Adrian-Strasse 3", "dir"))
# Out:
# Directions:
# 1. Head northwest on Jasomirgottstraße (92.0 meters)
# 2. Turn left onto Bauernmarkt (120.5 meters)
# 3. Turn right onto Petersplatz (65.6 meters)
# 4. Continue straight onto Milchgasse (93.1 meters)
# 5. Turn right onto Brandstätte (282.7 meters)
# 6. Turn right onto Wollzeile (590.0 meters)
# 7. Turn sharp right onto Parkring (786.0 meters)
# 8. Turn left onto Schwarzenbergplatz (161.0 meters)
# 9. Turn right onto Lothringerstraße, B1 (3259.0 meters)
# 10. Keep right onto Linke Wienzeile, B1 (8744.6 meters)
# 11. Keep left onto West Autobahn, A1 (282258.4 meters)
# 12. Keep right (145.0 meters)
# 13. Keep left (137.8 meters)
# 14. Enter the roundabout and take the 3rd exit onto Münchner Bundesstraße, B155 (1982.0 meters)
# 15. Turn right onto Rudolf-Biebl-Straße, B1 (644.3 meters)
# 16. Turn right onto Innsbrucker Bundesstraße, B1 (237.8 meters)
# 17. Turn right onto Wilhelm-Erben-Straße (79.0 meters)
# 18. Turn right onto Karl-Adrian-Straße (126.8 meters)
# ...
